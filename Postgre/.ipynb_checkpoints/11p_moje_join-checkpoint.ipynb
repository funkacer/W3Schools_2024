# %%
import psycopg2
import pandas as pd

# %%
# Connect to your postgres DB
conn = psycopg2.connect("dbname=test user=funka password=funka")

# %%
# Open a cursor to perform database operations
cur = conn.cursor()

# %%
# Execute a query
cur.execute('''
SELECT *, price * quantity AS order_value FROM public.order_details
LEFT JOIN public.orders
ON order_details.order_id = orders.order_id
LEFT JOIN public.products
ON order_details.product_id = products.product_id;
''') #int, datetime

# %%
# Retrieve query results
records = cur.fetchall()

# %%
df = pd.DataFrame((tuple(t) for t in records))
df.columns = [i[0] for i in cur.description]

# %%
df
# Out:
#       order_detail_id  order_id  product_id  quantity  order_id  customer_id  \
# 0                   1     10248          11        12     10248           90
# 1                   2     10248          42        10     10248           90
# 2                   3     10248          72         5     10248           90
# 3                   4     10249          14         9     10249           81
# 4                   5     10249          51        40     10249           81
# ...               ...       ...         ...       ...       ...          ...
# 2150             2151     11077          64         2     11077           65
# 2151             2152     11077          66         1     11077           65
# 2152             2153     11077          73         2     11077           65
# 2153             2154     11077          75         4     11077           65
# 2154             2155     11077          77         2     11077           65
#
#       order_date  product_id                     product_name  category_id  \
# 0     2021-07-04          11                   Queso Cabrales            4
# 1     2021-07-04          42    Singaporean Hokkien Fried Mee            5
# 2     2021-07-04          72           Mozzarella di Giovanni            4
# 3     2021-07-05          14                             Tofu            7
# 4     2021-07-05          51            Manjimup Dried Apples            7
# ...          ...         ...                              ...          ...
# 2150  2023-05-06          64        Wimmers gute Semmelknadel            5
# 2151  2023-05-06          66        Louisiana Hot Spiced Okra            2
# 2152  2023-05-06          73                       Red Kaviar            8
# 2153  2023-05-06          75             Rhenbreu Klosterbier            1
# 2154  2023-05-06          77  Original Frankfurter grőne Soae            2
#
#                     unit  price order_value
# 0              1 kg pkg.  21.00      252.00
# 1        32 - 1 kg pkgs.  14.00      140.00
# 2       24 - 200 g pkgs.  34.80      174.00
# 3       40 - 100 g pkgs.  23.25      209.25
# 4       50 - 300 g pkgs.  53.00     2120.00
# ...                  ...    ...         ...
# 2150  20 bags x 4 pieces  33.25       66.50
# 2151      24 - 8 oz jars  17.00       17.00
# 2152     24 - 150 g jars  15.00       30.00
# 2153  24 - 0.5 l bottles   7.75       31.00
# 2154            12 boxes  13.00       26.00
#
# [2155 rows x 13 columns]
