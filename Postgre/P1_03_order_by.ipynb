# %%
import psycopg2

# %%
# Connect to your postgres DB
conn = psycopg2.connect("dbname=test user=funka password=funka")

# %%
# Open a cursor to perform database operations
cur = conn.cursor()

# %%
# Execute a query
cur.execute('''SELECT * FROM products
ORDER BY price;''')

# %%
# Retrieve query results
records = cur.fetchall()

# %%
records
# Out:
# [(33, 'Geitost', 4, '500 g', Decimal('2.50')),
#  (24, 'Guarani Fantastica', 1, '12 - 355 ml cans', Decimal('4.50')),
#  (13, 'Konbu', 8, '2 kg box', Decimal('6.00')),
#  (52, 'Filo Mix', 5, '16 - 2 kg boxes', Decimal('7.00')),
#  (54, 'Tourtiare', 6, '16 pies', Decimal('7.45')),
#  (75, 'Rhenbreu Klosterbier', 1, '24 - 0.5 l bottles', Decimal('7.75')),
#  (23, 'Tunnbrod', 5, '12 - 250 g pkgs.', Decimal('9.00')),
#  (19,
#   'Teatime Chocolate Biscuits',
#   3,
#   '10 boxes x 12 pieces',
#   Decimal('9.20')),
#  (47, 'Zaanse koeken', 3, '10 - 4 oz boxes', Decimal('9.50')),
#  (45, 'Rogede sild', 8, '1k pkg.', Decimal('9.50')),
#  (41, 'Jacks New England Clam Chowder', 8, '12 - 12 oz cans', Decimal('9.65')),
#  (74, 'Longlife Tofu', 7, '5 kg pkg.', Decimal('10.00')),
#  (3, 'Aniseed Syrup', 2, '12 - 550 ml bottles', Decimal('10.00')),
#  (21, 'Sir Rodneys Scones', 3, '24 pkgs. x 4 pieces', Decimal('10.00')),
#  (46, 'Spegesild', 8, '4 - 450 g glasses', Decimal('12.00')),
#  (31, 'Gorgonzola Telino', 4, '12 - 100 g pkgs', Decimal('12.50')),
#  (68, 'Scottish Longbreads', 3, '10 boxes x 8 pieces', Decimal('12.50')),
#  (48, 'Chocolade', 3, '10 pkgs.', Decimal('12.75')),
#  (77, 'Original Frankfurter grőne Soae', 2, '12 boxes', Decimal('13.00')),
#  (58, 'Escargots de Bourgogne', 8, '24 pieces', Decimal('13.25')),
#  (42, 'Singaporean Hokkien Fried Mee', 5, '32 - 1 kg pkgs.', Decimal('14.00')),
#  (34, 'Sasquatch Ale', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (67, 'Laughing Lumberjack Lager', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (25, 'NuNuCa Nui-Nougat-Creme', 3, '20 - 450 g glasses', Decimal('14.00')),
#  (73, 'Red Kaviar', 8, '24 - 150 g jars', Decimal('15.00')),
#  (70, 'Outback Lager', 1, '24 - 355 ml bottles', Decimal('15.00')),
#  (15, 'Genen Shouyu', 2, '24 - 250 ml bottles', Decimal('15.50')),
#  (50, 'Valkoinen suklaa', 3, '12 - 100 g bars', Decimal('16.25')),
#  (66, 'Louisiana Hot Spiced Okra', 2, '24 - 8 oz jars', Decimal('17.00')),
#  (16, 'Pavlova', 3, '32 - 500 g boxes', Decimal('17.45')),
#  (39, 'Chartreuse verte', 1, '750 cc per bottle', Decimal('18.00')),
#  (35, 'Steeleye Stout', 1, '24 - 12 oz bottles', Decimal('18.00')),
#  (1, 'Chais', 1, '10 boxes x 20 bags', Decimal('18.00')),
#  (76, 'Lakkalikeeri', 1, '500 ml ', Decimal('18.00')),
#  (40, 'Boston Crab Meat', 8, '24 - 4 oz tins', Decimal('18.40')),
#  (36, 'Inlagd Sill', 8, '24 - 250 g jars', Decimal('19.00')),
#  (2, 'Chang', 1, '24 - 12 oz bottles', Decimal('19.00')),
#  (44, 'Gula Malacca', 2, '20 - 2 kg bags', Decimal('19.45')),
#  (57, 'Ravioli Angelo', 5, '24 - 250 g pkgs.', Decimal('19.50')),
#  (49, 'Maxilaku', 3, '24 - 50 g pkgs.', Decimal('20.00')),
#  (11, 'Queso Cabrales', 4, '1 kg pkg.', Decimal('21.00')),
#  (22, 'Gustafs Kneckebrod', 5, '24 - 500 g pkgs.', Decimal('21.00')),
#  (65,
#   'Louisiana Fiery Hot Pepper Sauce',
#   2,
#   '32 - 8 oz bottles',
#   Decimal('21.05')),
#  (5, 'Chef Antons Gumbo Mix', 2, '36 boxes', Decimal('21.35')),
#  (71, 'Flotemysost', 4, '10 - 500 g pkgs.', Decimal('21.50')),
#  (4, 'Chef Antons Cajun Seasoning', 2, '48 - 6 oz jars', Decimal('22.00')),
#  (14, 'Tofu', 7, '40 - 100 g pkgs.', Decimal('23.25')),
#  (55, 'Pate chinois', 6, '24 boxes x 2 pies', Decimal('24.00')),
#  (6, 'Grandmas Boysenberry Spread', 2, '12 - 8 oz jars', Decimal('25.00')),
#  (30, 'Nord-Ost Matjeshering', 8, '10 - 200 g glasses', Decimal('25.89')),
#  (37, 'Gravad lax', 8, '12 - 500 g pkgs.', Decimal('26.00')),
#  (61, 'Sirop d arable', 2, '24 - 500 ml bottles', Decimal('28.50')),
#  (7, 'Uncle Bobs Organic Dried Pears', 7, '12 - 1 lb pkgs.', Decimal('30.00')),
#  (10, 'Ikura', 8, '12 - 200 ml jars', Decimal('31.00')),
#  (26, 'Gumber Gummiberchen', 3, '100 - 250 g bags', Decimal('31.23')),
#  (32, 'Mascarpone Fabioli', 4, '24 - 200 g pkgs.', Decimal('32.00')),
#  (53, 'Perth Pasties', 6, '48 pieces', Decimal('32.80')),
#  (64, 'Wimmers gute Semmelknadel', 5, '20 bags x 4 pieces', Decimal('33.25')),
#  (60, 'Camembert Pierrot', 4, '15 - 300 g rounds', Decimal('34.00')),
#  (72, 'Mozzarella di Giovanni', 4, '24 - 200 g pkgs.', Decimal('34.80')),
#  (69, 'Gudbrandsdalsost', 4, '10 kg pkg.', Decimal('36.00')),
#  (56, 'Gnocchi di nonna Alice', 5, '24 - 250 g pkgs.', Decimal('38.00')),
#  (12, 'Queso Manchego La Pastora', 4, '10 - 500 g pkgs.', Decimal('38.00')),
#  (17, 'Alice Mutton', 6, '20 - 1 kg tins', Decimal('39.00')),
#  (8, 'Northwoods Cranberry Sauce', 2, '12 - 12 oz jars', Decimal('40.00')),
#  (27, 'Schoggi Schokolade', 3, '100 - 100 g pieces', Decimal('43.90')),
#  (63, 'Vegie-spread', 2, '15 - 625 g jars', Decimal('43.90')),
#  (28, 'Rassle Sauerkraut', 7, '25 - 825 g cans', Decimal('45.60')),
#  (43, 'Ipoh Coffee', 1, '16 - 500 g tins', Decimal('46.00')),
#  (62, 'Tarte au sucre', 3, '48 pies', Decimal('49.30')),
#  (51, 'Manjimup Dried Apples', 7, '50 - 300 g pkgs.', Decimal('53.00')),
#  (59, 'Raclette Courdavault', 4, '5 kg pkg.', Decimal('55.00')),
#  (18, 'Carnarvon Tigers', 8, '16 kg pkg.', Decimal('62.50')),
#  (20, 'Sir Rodneys Marmalade', 3, '30 gift boxes', Decimal('81.00')),
#  (9, 'Mishi Kobe Niku', 6, '18 - 500 g pkgs.', Decimal('97.00')),
#  (29, 'Thoringer Rostbratwurst', 6, '50 bags x 30 sausgs.', Decimal('123.79')),
#  (38, 'Cote de Blaye', 1, '12 - 75 cl bottles', Decimal('263.50'))]

# %%
# Execute a query
cur.execute('''SELECT * FROM products
ORDER BY price DESC;''')

# %%
# Retrieve query results
records = cur.fetchall()

# %%
records
# Out:
# [(38, 'Cote de Blaye', 1, '12 - 75 cl bottles', Decimal('263.50')),
#  (29, 'Thoringer Rostbratwurst', 6, '50 bags x 30 sausgs.', Decimal('123.79')),
#  (9, 'Mishi Kobe Niku', 6, '18 - 500 g pkgs.', Decimal('97.00')),
#  (20, 'Sir Rodneys Marmalade', 3, '30 gift boxes', Decimal('81.00')),
#  (18, 'Carnarvon Tigers', 8, '16 kg pkg.', Decimal('62.50')),
#  (59, 'Raclette Courdavault', 4, '5 kg pkg.', Decimal('55.00')),
#  (51, 'Manjimup Dried Apples', 7, '50 - 300 g pkgs.', Decimal('53.00')),
#  (62, 'Tarte au sucre', 3, '48 pies', Decimal('49.30')),
#  (43, 'Ipoh Coffee', 1, '16 - 500 g tins', Decimal('46.00')),
#  (28, 'Rassle Sauerkraut', 7, '25 - 825 g cans', Decimal('45.60')),
#  (27, 'Schoggi Schokolade', 3, '100 - 100 g pieces', Decimal('43.90')),
#  (63, 'Vegie-spread', 2, '15 - 625 g jars', Decimal('43.90')),
#  (8, 'Northwoods Cranberry Sauce', 2, '12 - 12 oz jars', Decimal('40.00')),
#  (17, 'Alice Mutton', 6, '20 - 1 kg tins', Decimal('39.00')),
#  (56, 'Gnocchi di nonna Alice', 5, '24 - 250 g pkgs.', Decimal('38.00')),
#  (12, 'Queso Manchego La Pastora', 4, '10 - 500 g pkgs.', Decimal('38.00')),
#  (69, 'Gudbrandsdalsost', 4, '10 kg pkg.', Decimal('36.00')),
#  (72, 'Mozzarella di Giovanni', 4, '24 - 200 g pkgs.', Decimal('34.80')),
#  (60, 'Camembert Pierrot', 4, '15 - 300 g rounds', Decimal('34.00')),
#  (64, 'Wimmers gute Semmelknadel', 5, '20 bags x 4 pieces', Decimal('33.25')),
#  (53, 'Perth Pasties', 6, '48 pieces', Decimal('32.80')),
#  (32, 'Mascarpone Fabioli', 4, '24 - 200 g pkgs.', Decimal('32.00')),
#  (26, 'Gumber Gummiberchen', 3, '100 - 250 g bags', Decimal('31.23')),
#  (10, 'Ikura', 8, '12 - 200 ml jars', Decimal('31.00')),
#  (7, 'Uncle Bobs Organic Dried Pears', 7, '12 - 1 lb pkgs.', Decimal('30.00')),
#  (61, 'Sirop d arable', 2, '24 - 500 ml bottles', Decimal('28.50')),
#  (37, 'Gravad lax', 8, '12 - 500 g pkgs.', Decimal('26.00')),
#  (30, 'Nord-Ost Matjeshering', 8, '10 - 200 g glasses', Decimal('25.89')),
#  (6, 'Grandmas Boysenberry Spread', 2, '12 - 8 oz jars', Decimal('25.00')),
#  (55, 'Pate chinois', 6, '24 boxes x 2 pies', Decimal('24.00')),
#  (14, 'Tofu', 7, '40 - 100 g pkgs.', Decimal('23.25')),
#  (4, 'Chef Antons Cajun Seasoning', 2, '48 - 6 oz jars', Decimal('22.00')),
#  (71, 'Flotemysost', 4, '10 - 500 g pkgs.', Decimal('21.50')),
#  (5, 'Chef Antons Gumbo Mix', 2, '36 boxes', Decimal('21.35')),
#  (65,
#   'Louisiana Fiery Hot Pepper Sauce',
#   2,
#   '32 - 8 oz bottles',
#   Decimal('21.05')),
#  (11, 'Queso Cabrales', 4, '1 kg pkg.', Decimal('21.00')),
#  (22, 'Gustafs Kneckebrod', 5, '24 - 500 g pkgs.', Decimal('21.00')),
#  (49, 'Maxilaku', 3, '24 - 50 g pkgs.', Decimal('20.00')),
#  (57, 'Ravioli Angelo', 5, '24 - 250 g pkgs.', Decimal('19.50')),
#  (44, 'Gula Malacca', 2, '20 - 2 kg bags', Decimal('19.45')),
#  (36, 'Inlagd Sill', 8, '24 - 250 g jars', Decimal('19.00')),
#  (2, 'Chang', 1, '24 - 12 oz bottles', Decimal('19.00')),
#  (40, 'Boston Crab Meat', 8, '24 - 4 oz tins', Decimal('18.40')),
#  (1, 'Chais', 1, '10 boxes x 20 bags', Decimal('18.00')),
#  (35, 'Steeleye Stout', 1, '24 - 12 oz bottles', Decimal('18.00')),
#  (39, 'Chartreuse verte', 1, '750 cc per bottle', Decimal('18.00')),
#  (76, 'Lakkalikeeri', 1, '500 ml ', Decimal('18.00')),
#  (16, 'Pavlova', 3, '32 - 500 g boxes', Decimal('17.45')),
#  (66, 'Louisiana Hot Spiced Okra', 2, '24 - 8 oz jars', Decimal('17.00')),
#  (50, 'Valkoinen suklaa', 3, '12 - 100 g bars', Decimal('16.25')),
#  (15, 'Genen Shouyu', 2, '24 - 250 ml bottles', Decimal('15.50')),
#  (70, 'Outback Lager', 1, '24 - 355 ml bottles', Decimal('15.00')),
#  (73, 'Red Kaviar', 8, '24 - 150 g jars', Decimal('15.00')),
#  (34, 'Sasquatch Ale', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (42, 'Singaporean Hokkien Fried Mee', 5, '32 - 1 kg pkgs.', Decimal('14.00')),
#  (25, 'NuNuCa Nui-Nougat-Creme', 3, '20 - 450 g glasses', Decimal('14.00')),
#  (67, 'Laughing Lumberjack Lager', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (58, 'Escargots de Bourgogne', 8, '24 pieces', Decimal('13.25')),
#  (77, 'Original Frankfurter grőne Soae', 2, '12 boxes', Decimal('13.00')),
#  (48, 'Chocolade', 3, '10 pkgs.', Decimal('12.75')),
#  (31, 'Gorgonzola Telino', 4, '12 - 100 g pkgs', Decimal('12.50')),
#  (68, 'Scottish Longbreads', 3, '10 boxes x 8 pieces', Decimal('12.50')),
#  (46, 'Spegesild', 8, '4 - 450 g glasses', Decimal('12.00')),
#  (21, 'Sir Rodneys Scones', 3, '24 pkgs. x 4 pieces', Decimal('10.00')),
#  (3, 'Aniseed Syrup', 2, '12 - 550 ml bottles', Decimal('10.00')),
#  (74, 'Longlife Tofu', 7, '5 kg pkg.', Decimal('10.00')),
#  (41, 'Jacks New England Clam Chowder', 8, '12 - 12 oz cans', Decimal('9.65')),
#  (45, 'Rogede sild', 8, '1k pkg.', Decimal('9.50')),
#  (47, 'Zaanse koeken', 3, '10 - 4 oz boxes', Decimal('9.50')),
#  (19,
#   'Teatime Chocolate Biscuits',
#   3,
#   '10 boxes x 12 pieces',
#   Decimal('9.20')),
#  (23, 'Tunnbrod', 5, '12 - 250 g pkgs.', Decimal('9.00')),
#  (75, 'Rhenbreu Klosterbier', 1, '24 - 0.5 l bottles', Decimal('7.75')),
#  (54, 'Tourtiare', 6, '16 pies', Decimal('7.45')),
#  (52, 'Filo Mix', 5, '16 - 2 kg boxes', Decimal('7.00')),
#  (13, 'Konbu', 8, '2 kg box', Decimal('6.00')),
#  (24, 'Guarani Fantastica', 1, '12 - 355 ml cans', Decimal('4.50')),
#  (33, 'Geitost', 4, '500 g', Decimal('2.50'))]

# %%
# Execute a query
cur.execute('''SELECT * FROM products
ORDER BY product_name;''')

# %%
# Retrieve query results
records = cur.fetchall()

# %%
records
# Out:
# [(17, 'Alice Mutton', 6, '20 - 1 kg tins', Decimal('39.00')),
#  (3, 'Aniseed Syrup', 2, '12 - 550 ml bottles', Decimal('10.00')),
#  (40, 'Boston Crab Meat', 8, '24 - 4 oz tins', Decimal('18.40')),
#  (60, 'Camembert Pierrot', 4, '15 - 300 g rounds', Decimal('34.00')),
#  (18, 'Carnarvon Tigers', 8, '16 kg pkg.', Decimal('62.50')),
#  (1, 'Chais', 1, '10 boxes x 20 bags', Decimal('18.00')),
#  (2, 'Chang', 1, '24 - 12 oz bottles', Decimal('19.00')),
#  (39, 'Chartreuse verte', 1, '750 cc per bottle', Decimal('18.00')),
#  (4, 'Chef Antons Cajun Seasoning', 2, '48 - 6 oz jars', Decimal('22.00')),
#  (5, 'Chef Antons Gumbo Mix', 2, '36 boxes', Decimal('21.35')),
#  (48, 'Chocolade', 3, '10 pkgs.', Decimal('12.75')),
#  (38, 'Cote de Blaye', 1, '12 - 75 cl bottles', Decimal('263.50')),
#  (58, 'Escargots de Bourgogne', 8, '24 pieces', Decimal('13.25')),
#  (52, 'Filo Mix', 5, '16 - 2 kg boxes', Decimal('7.00')),
#  (71, 'Flotemysost', 4, '10 - 500 g pkgs.', Decimal('21.50')),
#  (33, 'Geitost', 4, '500 g', Decimal('2.50')),
#  (15, 'Genen Shouyu', 2, '24 - 250 ml bottles', Decimal('15.50')),
#  (56, 'Gnocchi di nonna Alice', 5, '24 - 250 g pkgs.', Decimal('38.00')),
#  (31, 'Gorgonzola Telino', 4, '12 - 100 g pkgs', Decimal('12.50')),
#  (6, 'Grandmas Boysenberry Spread', 2, '12 - 8 oz jars', Decimal('25.00')),
#  (37, 'Gravad lax', 8, '12 - 500 g pkgs.', Decimal('26.00')),
#  (24, 'Guarani Fantastica', 1, '12 - 355 ml cans', Decimal('4.50')),
#  (69, 'Gudbrandsdalsost', 4, '10 kg pkg.', Decimal('36.00')),
#  (44, 'Gula Malacca', 2, '20 - 2 kg bags', Decimal('19.45')),
#  (26, 'Gumber Gummiberchen', 3, '100 - 250 g bags', Decimal('31.23')),
#  (22, 'Gustafs Kneckebrod', 5, '24 - 500 g pkgs.', Decimal('21.00')),
#  (10, 'Ikura', 8, '12 - 200 ml jars', Decimal('31.00')),
#  (36, 'Inlagd Sill', 8, '24 - 250 g jars', Decimal('19.00')),
#  (43, 'Ipoh Coffee', 1, '16 - 500 g tins', Decimal('46.00')),
#  (41, 'Jacks New England Clam Chowder', 8, '12 - 12 oz cans', Decimal('9.65')),
#  (13, 'Konbu', 8, '2 kg box', Decimal('6.00')),
#  (76, 'Lakkalikeeri', 1, '500 ml ', Decimal('18.00')),
#  (67, 'Laughing Lumberjack Lager', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (74, 'Longlife Tofu', 7, '5 kg pkg.', Decimal('10.00')),
#  (65,
#   'Louisiana Fiery Hot Pepper Sauce',
#   2,
#   '32 - 8 oz bottles',
#   Decimal('21.05')),
#  (66, 'Louisiana Hot Spiced Okra', 2, '24 - 8 oz jars', Decimal('17.00')),
#  (51, 'Manjimup Dried Apples', 7, '50 - 300 g pkgs.', Decimal('53.00')),
#  (32, 'Mascarpone Fabioli', 4, '24 - 200 g pkgs.', Decimal('32.00')),
#  (49, 'Maxilaku', 3, '24 - 50 g pkgs.', Decimal('20.00')),
#  (9, 'Mishi Kobe Niku', 6, '18 - 500 g pkgs.', Decimal('97.00')),
#  (72, 'Mozzarella di Giovanni', 4, '24 - 200 g pkgs.', Decimal('34.80')),
#  (30, 'Nord-Ost Matjeshering', 8, '10 - 200 g glasses', Decimal('25.89')),
#  (8, 'Northwoods Cranberry Sauce', 2, '12 - 12 oz jars', Decimal('40.00')),
#  (25, 'NuNuCa Nui-Nougat-Creme', 3, '20 - 450 g glasses', Decimal('14.00')),
#  (77, 'Original Frankfurter grőne Soae', 2, '12 boxes', Decimal('13.00')),
#  (70, 'Outback Lager', 1, '24 - 355 ml bottles', Decimal('15.00')),
#  (55, 'Pate chinois', 6, '24 boxes x 2 pies', Decimal('24.00')),
#  (16, 'Pavlova', 3, '32 - 500 g boxes', Decimal('17.45')),
#  (53, 'Perth Pasties', 6, '48 pieces', Decimal('32.80')),
#  (11, 'Queso Cabrales', 4, '1 kg pkg.', Decimal('21.00')),
#  (12, 'Queso Manchego La Pastora', 4, '10 - 500 g pkgs.', Decimal('38.00')),
#  (59, 'Raclette Courdavault', 4, '5 kg pkg.', Decimal('55.00')),
#  (28, 'Rassle Sauerkraut', 7, '25 - 825 g cans', Decimal('45.60')),
#  (57, 'Ravioli Angelo', 5, '24 - 250 g pkgs.', Decimal('19.50')),
#  (73, 'Red Kaviar', 8, '24 - 150 g jars', Decimal('15.00')),
#  (75, 'Rhenbreu Klosterbier', 1, '24 - 0.5 l bottles', Decimal('7.75')),
#  (45, 'Rogede sild', 8, '1k pkg.', Decimal('9.50')),
#  (34, 'Sasquatch Ale', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (27, 'Schoggi Schokolade', 3, '100 - 100 g pieces', Decimal('43.90')),
#  (68, 'Scottish Longbreads', 3, '10 boxes x 8 pieces', Decimal('12.50')),
#  (42, 'Singaporean Hokkien Fried Mee', 5, '32 - 1 kg pkgs.', Decimal('14.00')),
#  (20, 'Sir Rodneys Marmalade', 3, '30 gift boxes', Decimal('81.00')),
#  (21, 'Sir Rodneys Scones', 3, '24 pkgs. x 4 pieces', Decimal('10.00')),
#  (61, 'Sirop d arable', 2, '24 - 500 ml bottles', Decimal('28.50')),
#  (46, 'Spegesild', 8, '4 - 450 g glasses', Decimal('12.00')),
#  (35, 'Steeleye Stout', 1, '24 - 12 oz bottles', Decimal('18.00')),
#  (62, 'Tarte au sucre', 3, '48 pies', Decimal('49.30')),
#  (19,
#   'Teatime Chocolate Biscuits',
#   3,
#   '10 boxes x 12 pieces',
#   Decimal('9.20')),
#  (29, 'Thoringer Rostbratwurst', 6, '50 bags x 30 sausgs.', Decimal('123.79')),
#  (14, 'Tofu', 7, '40 - 100 g pkgs.', Decimal('23.25')),
#  (54, 'Tourtiare', 6, '16 pies', Decimal('7.45')),
#  (23, 'Tunnbrod', 5, '12 - 250 g pkgs.', Decimal('9.00')),
#  (7, 'Uncle Bobs Organic Dried Pears', 7, '12 - 1 lb pkgs.', Decimal('30.00')),
#  (50, 'Valkoinen suklaa', 3, '12 - 100 g bars', Decimal('16.25')),
#  (63, 'Vegie-spread', 2, '15 - 625 g jars', Decimal('43.90')),
#  (64, 'Wimmers gute Semmelknadel', 5, '20 bags x 4 pieces', Decimal('33.25')),
#  (47, 'Zaanse koeken', 3, '10 - 4 oz boxes', Decimal('9.50'))]

# %%
# Execute a query
cur.execute('''SELECT * FROM products
ORDER BY product_name DESC;''')

# %%
# Retrieve query results
records = cur.fetchall()

# %%
records
# Out:
# [(47, 'Zaanse koeken', 3, '10 - 4 oz boxes', Decimal('9.50')),
#  (64, 'Wimmers gute Semmelknadel', 5, '20 bags x 4 pieces', Decimal('33.25')),
#  (63, 'Vegie-spread', 2, '15 - 625 g jars', Decimal('43.90')),
#  (50, 'Valkoinen suklaa', 3, '12 - 100 g bars', Decimal('16.25')),
#  (7, 'Uncle Bobs Organic Dried Pears', 7, '12 - 1 lb pkgs.', Decimal('30.00')),
#  (23, 'Tunnbrod', 5, '12 - 250 g pkgs.', Decimal('9.00')),
#  (54, 'Tourtiare', 6, '16 pies', Decimal('7.45')),
#  (14, 'Tofu', 7, '40 - 100 g pkgs.', Decimal('23.25')),
#  (29, 'Thoringer Rostbratwurst', 6, '50 bags x 30 sausgs.', Decimal('123.79')),
#  (19,
#   'Teatime Chocolate Biscuits',
#   3,
#   '10 boxes x 12 pieces',
#   Decimal('9.20')),
#  (62, 'Tarte au sucre', 3, '48 pies', Decimal('49.30')),
#  (35, 'Steeleye Stout', 1, '24 - 12 oz bottles', Decimal('18.00')),
#  (46, 'Spegesild', 8, '4 - 450 g glasses', Decimal('12.00')),
#  (61, 'Sirop d arable', 2, '24 - 500 ml bottles', Decimal('28.50')),
#  (21, 'Sir Rodneys Scones', 3, '24 pkgs. x 4 pieces', Decimal('10.00')),
#  (20, 'Sir Rodneys Marmalade', 3, '30 gift boxes', Decimal('81.00')),
#  (42, 'Singaporean Hokkien Fried Mee', 5, '32 - 1 kg pkgs.', Decimal('14.00')),
#  (68, 'Scottish Longbreads', 3, '10 boxes x 8 pieces', Decimal('12.50')),
#  (27, 'Schoggi Schokolade', 3, '100 - 100 g pieces', Decimal('43.90')),
#  (34, 'Sasquatch Ale', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (45, 'Rogede sild', 8, '1k pkg.', Decimal('9.50')),
#  (75, 'Rhenbreu Klosterbier', 1, '24 - 0.5 l bottles', Decimal('7.75')),
#  (73, 'Red Kaviar', 8, '24 - 150 g jars', Decimal('15.00')),
#  (57, 'Ravioli Angelo', 5, '24 - 250 g pkgs.', Decimal('19.50')),
#  (28, 'Rassle Sauerkraut', 7, '25 - 825 g cans', Decimal('45.60')),
#  (59, 'Raclette Courdavault', 4, '5 kg pkg.', Decimal('55.00')),
#  (12, 'Queso Manchego La Pastora', 4, '10 - 500 g pkgs.', Decimal('38.00')),
#  (11, 'Queso Cabrales', 4, '1 kg pkg.', Decimal('21.00')),
#  (53, 'Perth Pasties', 6, '48 pieces', Decimal('32.80')),
#  (16, 'Pavlova', 3, '32 - 500 g boxes', Decimal('17.45')),
#  (55, 'Pate chinois', 6, '24 boxes x 2 pies', Decimal('24.00')),
#  (70, 'Outback Lager', 1, '24 - 355 ml bottles', Decimal('15.00')),
#  (77, 'Original Frankfurter grőne Soae', 2, '12 boxes', Decimal('13.00')),
#  (25, 'NuNuCa Nui-Nougat-Creme', 3, '20 - 450 g glasses', Decimal('14.00')),
#  (8, 'Northwoods Cranberry Sauce', 2, '12 - 12 oz jars', Decimal('40.00')),
#  (30, 'Nord-Ost Matjeshering', 8, '10 - 200 g glasses', Decimal('25.89')),
#  (72, 'Mozzarella di Giovanni', 4, '24 - 200 g pkgs.', Decimal('34.80')),
#  (9, 'Mishi Kobe Niku', 6, '18 - 500 g pkgs.', Decimal('97.00')),
#  (49, 'Maxilaku', 3, '24 - 50 g pkgs.', Decimal('20.00')),
#  (32, 'Mascarpone Fabioli', 4, '24 - 200 g pkgs.', Decimal('32.00')),
#  (51, 'Manjimup Dried Apples', 7, '50 - 300 g pkgs.', Decimal('53.00')),
#  (66, 'Louisiana Hot Spiced Okra', 2, '24 - 8 oz jars', Decimal('17.00')),
#  (65,
#   'Louisiana Fiery Hot Pepper Sauce',
#   2,
#   '32 - 8 oz bottles',
#   Decimal('21.05')),
#  (74, 'Longlife Tofu', 7, '5 kg pkg.', Decimal('10.00')),
#  (67, 'Laughing Lumberjack Lager', 1, '24 - 12 oz bottles', Decimal('14.00')),
#  (76, 'Lakkalikeeri', 1, '500 ml ', Decimal('18.00')),
#  (13, 'Konbu', 8, '2 kg box', Decimal('6.00')),
#  (41, 'Jacks New England Clam Chowder', 8, '12 - 12 oz cans', Decimal('9.65')),
#  (43, 'Ipoh Coffee', 1, '16 - 500 g tins', Decimal('46.00')),
#  (36, 'Inlagd Sill', 8, '24 - 250 g jars', Decimal('19.00')),
#  (10, 'Ikura', 8, '12 - 200 ml jars', Decimal('31.00')),
#  (22, 'Gustafs Kneckebrod', 5, '24 - 500 g pkgs.', Decimal('21.00')),
#  (26, 'Gumber Gummiberchen', 3, '100 - 250 g bags', Decimal('31.23')),
#  (44, 'Gula Malacca', 2, '20 - 2 kg bags', Decimal('19.45')),
#  (69, 'Gudbrandsdalsost', 4, '10 kg pkg.', Decimal('36.00')),
#  (24, 'Guarani Fantastica', 1, '12 - 355 ml cans', Decimal('4.50')),
#  (37, 'Gravad lax', 8, '12 - 500 g pkgs.', Decimal('26.00')),
#  (6, 'Grandmas Boysenberry Spread', 2, '12 - 8 oz jars', Decimal('25.00')),
#  (31, 'Gorgonzola Telino', 4, '12 - 100 g pkgs', Decimal('12.50')),
#  (56, 'Gnocchi di nonna Alice', 5, '24 - 250 g pkgs.', Decimal('38.00')),
#  (15, 'Genen Shouyu', 2, '24 - 250 ml bottles', Decimal('15.50')),
#  (33, 'Geitost', 4, '500 g', Decimal('2.50')),
#  (71, 'Flotemysost', 4, '10 - 500 g pkgs.', Decimal('21.50')),
#  (52, 'Filo Mix', 5, '16 - 2 kg boxes', Decimal('7.00')),
#  (58, 'Escargots de Bourgogne', 8, '24 pieces', Decimal('13.25')),
#  (38, 'Cote de Blaye', 1, '12 - 75 cl bottles', Decimal('263.50')),
#  (48, 'Chocolade', 3, '10 pkgs.', Decimal('12.75')),
#  (5, 'Chef Antons Gumbo Mix', 2, '36 boxes', Decimal('21.35')),
#  (4, 'Chef Antons Cajun Seasoning', 2, '48 - 6 oz jars', Decimal('22.00')),
#  (39, 'Chartreuse verte', 1, '750 cc per bottle', Decimal('18.00')),
#  (2, 'Chang', 1, '24 - 12 oz bottles', Decimal('19.00')),
#  (1, 'Chais', 1, '10 boxes x 20 bags', Decimal('18.00')),
#  (18, 'Carnarvon Tigers', 8, '16 kg pkg.', Decimal('62.50')),
#  (60, 'Camembert Pierrot', 4, '15 - 300 g rounds', Decimal('34.00')),
#  (40, 'Boston Crab Meat', 8, '24 - 4 oz tins', Decimal('18.40')),
#  (3, 'Aniseed Syrup', 2, '12 - 550 ml bottles', Decimal('10.00')),
#  (17, 'Alice Mutton', 6, '20 - 1 kg tins', Decimal('39.00'))]
