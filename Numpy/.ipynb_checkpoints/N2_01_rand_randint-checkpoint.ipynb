# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Mustry:
# sns.histplot([0, 1, 2, 3, 4, 5], kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4), discrete=True, element="poly")
# sns.kdeplot([0, 1, 2, 3, 4, 5])

# %% [markdown]
# Generate Random Number
#
# - NumPy offers the random module to work with random numbers.

# %%
# Generate a random integer from 0 to 100:
x = np.random.randint(100)
print(x)
# Out:
# 23

# %% [markdown]
# Generate Random Float
#
# - The random module's rand() method returns a random float between 0 and 1.

# %%
# Generate a random float from 0 to 1:
x = np.random.rand()
print(x)
# Out:
# 0.6004169048852345

# %% [markdown]
# Generate Random Array
#
# - In NumPy we work with arrays, and you can use the two methods from the above examples to make random arrays.

# %% [markdown]
# Integers
#
# - The randint() method takes a size parameter where you can specify the shape of an array.

# %%
# Generate a 1-D array containing 5 random integers from 0 to 100:
x=np.random.randint(100, size=(5))
print(x)
# Out:
# [16  8 76 17 83]

# %%
sns.histplot(x, kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4), discrete=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# Generate a 2-D array with 3 rows, each row containing 5 random integers from 0 to 100:
x = np.random.randint(100, size=(3, 5))
print(x)
# Out:
# [[ 3 53 97 48 85]
#  [12 19 17 78 82]
#  [80 40  0 89 88]]

# %%
sns.histplot(x, kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4), discrete=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Floats
#
# - The rand() method also allows you to specify the shape of the array.

# %%
# Generate a 1-D array containing 5 random floats:
x = np.random.rand(5)
print(x)
# Out:
# [0.6165244  0.34357127 0.4441806  0.87513198 0.90134238]

# %%
sns.histplot(x, kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4), element="poly")
# Out:
# <Axes: ylabel='Density'>

# %%
# Generate a 2-D array with 3 rows, each row containing 5 random numbers:
x = np.random.rand(3, 5)
print(x)
# Out:
# [[0.95288506 0.84153532 0.16540784 0.1370213  0.81777858]
#  [0.81060515 0.57840003 0.27017367 0.61368724 0.79147013]
#  [0.95709236 0.00588338 0.77681586 0.27240104 0.66984684]]

# %%
sns.histplot(x, kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4), element="poly")
# Out:
# <Axes: ylabel='Density'>
