# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Mustry:
# sns.histplot([0, 1, 2, 3, 4, 5], kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4), discrete=True, element="poly")
# sns.kdeplot([0, 1, 2, 3, 4, 5])

# %%
x = np.random.choice([1, 2], p=[0.5, 0.5], size=(100))
print(x)
# Out:
# [1 1 2 2 2 2 1 1 1 2 1 1 2 1 2 1 1 2 1 2 2 1 1 2 2 2 1 2 2 1 2 1 1 2 2 2 2
#  1 2 2 1 1 2 2 1 1 1 1 1 1 1 1 2 2 1 2 1 2 2 2 2 1 2 2 1 1 2 2 2 2 1 2 1 2
#  1 1 2 2 2 2 1 2 2 2 1 1 1 1 2 2 1 2 2 2 2 2 2 1 2 2]

# %%
unique, counts = np.unique(x, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {1: 44, 2: 56}

# %%
sns.histplot(x, kde=True, stat="density", kde_kws=dict(cut=3), alpha=.4, edgecolor=(1, 1, 1, .4), discrete=True)
# Out:
# <Axes: ylabel='Density'>
