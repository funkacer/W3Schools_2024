# %%
from MySQLdb import connect
import pandas as pd

# %%
# Connect to your MySQLdb
conn = connect(host='localhost', user='root')

# %%
# Open a cursor to perform database operations
cur = conn.cursor()

# %% [markdown]
# The SQL OR Operator
# - The WHERE clause can contain one or more OR operators.
# - The OR operator is used to filter records based on more than one condition, like if you want to return all customers from Germany but also those from Spain:

# %%
# Select all customers from Germany or Spain:
cur.execute('''SELECT * FROM sqlw3s.Customers WHERE Country = 'Germany' OR Country = 'Spain';''')
df = pd.DataFrame(tuple(t) for t in cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#     CustomerID                          CustomerName          ContactName  \
# 0            1                   Alfreds Futterkiste         Maria Anders
# 1            6               Blauer See Delikatessen           Hanna Moos
# 2            8             Bólido Comidas preparadas        Martín Sommer
# 3           17             Drachenblut Delikatessend         Sven Ottlieb
# 4           22  FISSA Fabrica Inter. Salchichas S.A.           Diego Roel
# 5           25                        Frankenversand        Peter Franken
# 6           29                Galería del gastrónomo     Eduardo Saavedra
# 7           30                   Godos Cocina Típica    José Pedro Freyre
# 8           39                       Königlich Essen        Philip Cramer
# 9           44                   Lehmanns Marktstand       Renate Messner
# 10          52                Morgenstern Gesundkost      Alexander Feuer
# 11          56                    Ottilies Käseladen  Henriette Pfalzheim
# ...

# %% [markdown]
# > Syntax
# >
# > SELECT column1, column2, ...
# > FROM table_name
# > WHERE condition1 OR condition2 OR condition3 ...;
#
# OR vs AND
# - The OR operator displays a record if any of the conditions are TRUE.
# - The AND operator displays a record if all the conditions are TRUE.
#
#
# At Least One Condition Must Be True
# - The following SQL statement selects all fields from Customers where either City is "Berlin", CustomerName starts with the letter "G" or Country is "Norway":

# %%
# Example
cur.execute('''SELECT * FROM sqlw3s.Customers WHERE City = 'Berlin' OR CustomerName LIKE 'G%' OR Country = 'Norway';''')
df = pd.DataFrame(tuple(t) for t in cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#    CustomerID             CustomerName        ContactName  \
# 0           1      Alfreds Futterkiste       Maria Anders
# 1          29   Galería del gastrónomo   Eduardo Saavedra
# 2          30      Godos Cocina Típica  José Pedro Freyre
# 3          31      Gourmet Lanchonetes      André Fonseca
# 4          32  Great Lakes Food Market      Howard Snyder
# 5          33     GROSELLA-Restaurante     Manuel Pereira
# 6          70            Santé Gourmet   Jonas Bergulfsen
#
#                      Address       City PostalCode    Country
# 0              Obere Str. 57     Berlin      12209    Germany
# 1     Rambla de Cataluña, 23  Barcelona      08022      Spain
# 2              C/ Romero, 33    Sevilla      41101      Spain
# 3            Av. Brasil, 442   Campinas  04876-786     Brazil
# 4           2732 Baker Blvd.     Eugene      97403        USA
# 5  5ª Ave. Los Palos Grandes    Caracas       1081  Venezuela
# 6     Erling Skakkes gate 78    Stavern       4110     Norway

# %% [markdown]
# Combining AND and OR
# - You can combine the AND and OR operators.
# - The following SQL statement selects all customers from Spain that starts with a "G" or an "R".
# - Make sure you use parenthesis to get the correct result.

# %%
# Select all Spanish customers that starts with either "G" or "R":
cur.execute('''SELECT * FROM sqlw3s.Customers WHERE Country = 'Spain' AND (CustomerName LIKE 'G%' OR CustomerName LIKE 'R%');''')
df = pd.DataFrame(tuple(t) for t in cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#    CustomerID            CustomerName        ContactName  \
# 0          29  Galería del gastrónomo   Eduardo Saavedra
# 1          30     Godos Cocina Típica  José Pedro Freyre
# 2          69        Romero y tomillo   Alejandra Camino
#
#                   Address       City PostalCode Country
# 0  Rambla de Cataluña, 23  Barcelona      08022   Spain
# 1           C/ Romero, 33    Sevilla      41101   Spain
# 2             Gran Vía, 1     Madrid      28001   Spain

# %% [markdown]
# Without parenthesis, the select statement will return all customers from Spain that starts with a "G", plus all customers that starts with an "R", regardless of the country value:

# %%
# Select all customers that either: are from Spain and starts with either "G", or starts with the letter "R":
cur.execute('''SELECT * FROM sqlw3s.Customers WHERE Country = 'Spain' AND CustomerName LIKE 'G%' OR CustomerName LIKE 'R%';''')
df = pd.DataFrame(tuple(t) for t in cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#    CustomerID                CustomerName        ContactName  \
# 0          29      Galería del gastrónomo   Eduardo Saavedra
# 1          30         Godos Cocina Típica  José Pedro Freyre
# 2          64               Rancho grande   Sergio Gutiérrez
# 3          65  Rattlesnake Canyon Grocery       Paula Wilson
# 4          66          Reggiani Caseifici    Maurizio Moroni
# 5          67          Ricardo Adocicados     Janete Limeira
# 6          68          Richter Supermarkt       Michael Holz
# 7          69            Romero y tomillo   Alejandra Camino
#
#                   Address            City PostalCode      Country
# 0  Rambla de Cataluña, 23       Barcelona      08022        Spain
# 1           C/ Romero, 33         Sevilla      41101        Spain
# 2  Av. del Libertador 900    Buenos Aires       1010    Argentina
# 3         2817 Milton Dr.     Albuquerque      87110          USA
# 4  Strada Provinciale 124   Reggio Emilia      42100        Italy
# ...
